# %% [markdown]
# # Generate instances

# %%
import random
import math

def printN(n):
    n = "n = " + str(n)
    return n

def createProtein():
    quantity = 1*random.randint(5,10)
    protein = random.randint(1, 30)*quantity
    carbohydrate = random.randint(1, 37)*quantity
    fat = random.randint(1, 30)*quantity
    calories = protein*4 + carbohydrate*4 + fat*9
    product = ""
    product = product + str(calories) + "," + str(protein) + "," + str(carbohydrate) + "," + str(fat) + "," + str(random.randint(50, 200)) + "," + str(random.randint(800, 4000)) + "|"
    return product

def createCarbohydrate():
    quantity = 1*random.randint(5,10)
    protein = random.randint(1, 15)*quantity
    carbohydrate = random.randint(1, 75)*quantity
    fat = random.randint(1, 30)*quantity
    calories = protein*4 + carbohydrate*4 + fat*9
    product = ""
    product = product + str(calories) + "," + str(protein) + "," + str(carbohydrate) + "," + str(fat) + "," + str(random.randint(50, 200)) + "," + str(random.randint(800, 4000)) + "|"
    return product

def createFat():
    quantity = 1*random.randint(5,10)
    protein = random.randint(1, 15)*quantity
    carbohydrate = random.randint(1, 37)*quantity
    fat = random.randint(1, 80)*quantity
    calories = protein*4 + carbohydrate*4 +fat*9
    product = ""
    product = product + str(calories) + "," + str(protein) + "," + str(carbohydrate) + "," + str(fat) + "," + str(random.randint(50, 200)) + "," + str(random.randint(800, 4000)) + "|"
    return product

def createGroceries(n):
    longitud = 0
    groceries = "[|"
    for i in range(0,math.floor(n/3)):
        groceries = groceries + createProtein()
        longitud = longitud + 1
    for i in range(0,math.floor(n/3)):
        groceries = groceries + createCarbohydrate()
        longitud = longitud + 1
    for i in range(0,math.floor(n/3)):
        groceries = groceries + createFat()
        longitud = longitud + 1
    for i in range(n-longitud):
        groceries = groceries + createCarbohydrate()
        longitud = longitud + 1
    groceries = groceries + "]"
    print("Len Groceries:"+ str(longitud))
    return groceries

def printGroceries(n):
    groceries = "groceries = " + str(createGroceries(n))
    return groceries

def createRequirements(d, p):
    #Redondear holgura < 2
    holgura = 1.1
    minprot = 38*d*p
    maxprot = int(46*d*p*holgura)
    mincar = 200*d*p
    maxcar = int(200*d*p*holgura)
    minfat = 57*d*p
    maxfat = int(62*d*p*holgura)
    mincal = minprot*4 + mincar*4 + minfat*9
    maxcal = maxprot*4 + maxcar*4 + maxfat*9
    requirements = "[|" + str(mincal) + "," + str(maxcal) + "|" + str(minprot) + "," + str(maxprot) + "|" + str(mincar) + "," + str(maxcar) + "|" + str(minfat) + "," + str(maxfat) + "|]"
    return requirements

def printRequirements(d, p):
    requirements = "requirements = " + str(createRequirements(d, p)) 
    return requirements

def createDZN(n):
#    days = random.randint(7,15)
#    people = random.randint(1,5)
    days = 4
    people = 4

    dzn = printN(n) + ";\n" + printGroceries(n) + ";\n" + printRequirements(days, people) + ";"
    print(dzn)
    print("Days = " + str(days))
    print("People = " + str(people))
    return(dzn)

#with open('/Users/juanj/Desktop/data.dzn', 'w') as f:
#    f.write(createDZN(100))

# PRUEBAS:
#    days = 7
#    people = 1
#    createDZN(50)

# %%
def create_IL(n):
    for i in range(n):
        path = '../instances/'+str(i)+'.dzn'
        #print(model)
        with open(path, 'w', encoding='utf8') as file_object:
            file_object.write(createDZN(2))
        print('created: Instance',i)

create_IL(2000)
# Out:
# Len Groceries:2
# n = 2;
# groceries = [|4599,9,675,207,92,1624|1700,40,340,20,61,2133|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 0
# Len Groceries:2
# n = 2;
# groceries = [|3458,105,350,182,114,2661|2640,78,312,120,124,2513|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 1
# Len Groceries:2
# n = 2;
# groceries = [|656,64,64,16,141,3701|3222,90,432,126,153,2140|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 2
# Len Groceries:2
# n = 2;
# groceries = [|2944,8,296,192,80,2719|1614,30,144,102,106,3866|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 3
# Len Groceries:2
# n = 2;
# groceries = [|1440,35,280,20,118,3473|1340,20,180,60,111,3839|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 4
# Len Groceries:2
# n = 2;
# groceries = [|2220,10,410,60,113,3058|3507,105,504,119,75,2620|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 5
# Len Groceries:2
# n = 2;
# groceries = [|2529,63,63,225,61,2365|3320,40,520,120,51,1408|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 6
# Len Groceries:2
# n = 2;
# groceries = [|5430,90,660,270,191,2807|4990,20,620,270,117,975|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 7
# Len Groceries:2
# n = 2;
# groceries = [|3546,117,567,90,66,1023|3582,63,549,126,97,2938|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 8
# Len Groceries:2
# n = 2;
# groceries = [|4730,30,500,290,125,868|770,77,21,42,66,1409|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 9
# Len Groceries:2
# n = 2;
# groceries = [|342,12,60,6,65,2852|4626,126,423,270,84,1666|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 10
# Len Groceries:2
# n = 2;
# groceries = [|1760,40,40,160,76,3703|2352,35,490,28,87,1106|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 11
# Len Groceries:2
# n = 2;
# groceries = [|3992,96,416,216,119,2772|3744,90,279,252,157,3360|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 12
# Len Groceries:2
# n = 2;
# groceries = [|2912,77,462,84,172,2458|3580,80,140,300,79,1108|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 13
# Len Groceries:2
# n = 2;
# groceries = [|2390,120,320,70,128,1991|1350,50,130,70,182,1613|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 14
# Len Groceries:2
# n = 2;
# groceries = [|3303,36,567,99,86,3479|4330,150,370,250,80,2251|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 15
# Len Groceries:2
# n = 2;
# groceries = [|3816,32,544,168,111,1587|2592,56,376,96,115,2037|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 16
# Len Groceries:2
# n = 2;
# groceries = [|2340,36,144,180,82,3414|3150,117,387,126,183,1672|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 17
# Len Groceries:2
# n = 2;
# groceries = [|3880,70,360,240,115,2004|1038,66,18,78,192,3122|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 18
# Len Groceries:2
# n = 2;
# groceries = [|3264,8,592,96,60,3688|3400,88,384,168,66,4000|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 19
# Len Groceries:2
# n = 2;
# groceries = [|948,6,204,12,189,2398|3768,32,568,152,121,2678|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 20
# Len Groceries:2
# n = 2;
# groceries = [|2410,10,480,50,130,2220|2322,90,450,18,132,3451|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 21
# Len Groceries:2
# n = 2;
# groceries = [|1824,36,312,48,152,2590|3550,20,350,230,155,2072|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 22
# Len Groceries:2
# n = 2;
# groceries = [|770,40,85,30,131,986|4570,60,520,250,150,1346|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 23
# Len Groceries:2
# n = 2;
# groceries = [|1800,6,174,120,92,2991|2230,70,240,110,184,2035|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 24
# Len Groceries:2
# n = 2;
# groceries = [|1272,48,216,24,72,3253|5130,90,585,270,158,3831|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 25
# Len Groceries:2
# n = 2;
# groceries = [|4040,40,340,280,150,973|3600,10,620,120,192,3903|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 26
# Len Groceries:2
# n = 2;
# groceries = [|3960,72,351,252,108,1602|1692,60,282,36,186,3202|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 27
# Len Groceries:2
# n = 2;
# groceries = [|1584,117,117,72,145,1292|4050,30,330,290,176,3820|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 28
# Len Groceries:2
# n = 2;
# groceries = [|2261,63,140,161,72,3394|3032,48,368,152,66,1011|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 29
# Len Groceries:2
# n = 2;
# groceries = [|1675,70,270,35,67,3814|3864,64,416,216,98,930|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 30
# Len Groceries:2
# n = 2;
# groceries = [|3288,56,568,88,54,3149|1908,90,252,60,63,1793|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 31
# Len Groceries:2
# n = 2;
# groceries = [|2005,25,195,125,120,2465|2688,8,304,160,129,1086|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 32
# Len Groceries:2
# n = 2;
# groceries = [|1700,45,155,100,112,2022|2556,45,351,108,101,969|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 33
# Len Groceries:2
# n = 2;
# groceries = [|3186,42,444,138,84,2004|3760,32,512,176,196,887|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 34
# Len Groceries:2
# n = 2;
# groceries = [|3740,140,300,220,51,2317|1736,49,133,112,183,2278|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 35
# Len Groceries:2
# n = 2;
# groceries = [|3690,70,650,90,166,3841|2772,42,210,196,170,1696|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 36
# Len Groceries:2
# n = 2;
# groceries = [|1680,65,175,80,97,3613|3789,90,513,153,54,3202|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 37
# Len Groceries:2
# n = 2;
# groceries = [|1326,42,60,102,141,3657|3260,140,360,140,188,2862|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 38
# Len Groceries:2
# n = 2;
# groceries = [|2289,63,147,161,162,825|819,105,84,7,121,3767|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 39
# Len Groceries:2
# n = 2;
# groceries = [|4797,36,657,225,162,2044|3500,90,740,20,137,2456|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 40
# Len Groceries:2
# n = 2;
# groceries = [|3392,96,536,96,108,1761|3560,48,392,200,79,1943|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 41
# Len Groceries:2
# n = 2;
# groceries = [|3550,30,250,270,52,3163|3696,84,525,140,76,3757|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 42
# Len Groceries:2
# n = 2;
# groceries = [|2485,55,375,85,104,3336|2646,24,246,174,122,1602|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 43
# Len Groceries:2
# n = 2;
# groceries = [|2460,30,315,120,105,1179|2538,36,342,114,123,1028|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 44
# Len Groceries:2
# n = 2;
# groceries = [|1160,100,10,80,108,2138|1384,104,224,8,98,1423|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 45
# Len Groceries:2
# n = 2;
# groceries = [|3762,27,387,234,84,3271|4490,40,610,210,193,3883|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 46
# Len Groceries:2
# n = 2;
# groceries = [|2492,42,392,84,163,2778|2450,40,370,90,130,889|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 47
# Len Groceries:2
# n = 2;
# groceries = [|2079,45,414,27,80,1776|1351,7,189,63,189,2400|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 48
# Len Groceries:2
# n = 2;
# groceries = [|1932,84,318,36,190,2092|3184,88,168,240,121,3383|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 49
# Len Groceries:2
# n = 2;
# groceries = [|1925,20,315,65,161,2725|1638,91,161,70,200,2391|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 50
# Len Groceries:2
# n = 2;
# groceries = [|2135,91,238,91,57,2935|2695,77,518,35,120,861|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 51
# Len Groceries:2
# n = 2;
# groceries = [|3960,63,522,180,50,1209|3276,105,399,140,143,3506|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 52
# Len Groceries:2
# n = 2;
# groceries = [|2421,36,387,81,171,2160|1314,66,168,42,162,3041|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 53
# Len Groceries:2
# n = 2;
# groceries = [|2115,75,330,55,58,3898|1975,35,290,75,195,3274|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 54
# Len Groceries:2
# n = 2;
# groceries = [|1351,42,28,119,135,2953|2184,32,208,136,94,2419|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 55
# Len Groceries:2
# n = 2;
# groceries = [|1944,63,180,108,149,3904|1035,65,70,55,67,1031|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 56
# Len Groceries:2
# n = 2;
# groceries = [|1340,50,60,100,185,3200|2370,72,372,66,74,2620|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 57
# Len Groceries:2
# n = 2;
# groceries = [|1120,20,170,40,87,2640|1638,14,364,14,141,3763|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 58
# Len Groceries:2
# n = 2;
# groceries = [|915,15,135,35,160,1781|2394,7,245,154,76,1970|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 59
# Len Groceries:2
# n = 2;
# groceries = [|1812,60,42,156,178,2179|2090,10,130,170,122,2851|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 60
# Len Groceries:2
# n = 2;
# groceries = [|3241,7,441,161,62,3802|2510,20,315,130,105,1391|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 61
# Len Groceries:2
# n = 2;
# groceries = [|1500,10,230,60,105,2731|2630,50,315,130,129,3157|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 62
# Len Groceries:2
# n = 2;
# groceries = [|2270,120,20,190,72,1387|1956,48,198,108,115,2016|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 63
# Len Groceries:2
# n = 2;
# groceries = [|1211,42,56,91,68,2297|2400,96,72,192,120,940|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 64
# Len Groceries:2
# n = 2;
# groceries = [|1888,112,216,64,187,2014|1085,45,215,5,126,3750|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 65
# Len Groceries:2
# n = 2;
# groceries = [|4080,80,670,120,170,3141|1547,105,77,91,126,1710|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 66
# Len Groceries:2
# n = 2;
# groceries = [|366,54,24,6,163,2623|4410,20,520,250,68,1923|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 67
# Len Groceries:2
# n = 2;
# groceries = [|1535,10,250,55,64,3907|1722,7,266,70,179,2477|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 68
# Len Groceries:2
# n = 2;
# groceries = [|3012,72,330,156,170,3198|1136,88,16,80,106,3788|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 69
# Len Groceries:2
# n = 2;
# groceries = [|4470,40,470,270,140,3317|1314,42,84,90,187,3635|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 70
# Len Groceries:2
# n = 2;
# groceries = [|1632,72,48,128,195,2043|2512,96,424,48,139,2577|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 71
# Len Groceries:2
# n = 2;
# groceries = [|4016,80,528,176,105,2780|2674,21,238,182,130,1109|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 72
# Len Groceries:2
# n = 2;
# groceries = [|4545,45,504,261,183,2829|2634,78,324,114,88,1187|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 73
# Len Groceries:2
# n = 2;
# groceries = [|2664,36,387,108,102,1997|1128,6,6,120,133,3508|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 74
# Len Groceries:2
# n = 2;
# groceries = [|1655,10,280,55,120,1680|3570,28,455,182,89,2204|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 75
# Len Groceries:2
# n = 2;
# groceries = [|635,15,20,55,84,2236|1710,48,204,78,113,2855|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 76
# Len Groceries:2
# n = 2;
# groceries = [|1395,60,120,75,179,2942|4460,140,300,300,113,3597|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 77
# Len Groceries:2
# n = 2;
# groceries = [|2336,32,480,32,147,3245|2538,63,369,90,108,1845|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 78
# Len Groceries:2
# n = 2;
# groceries = [|4060,80,260,300,186,1626|4330,140,560,170,73,3422|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 79
# Len Groceries:2
# n = 2;
# groceries = [|3731,70,406,203,181,2510|3960,140,490,160,50,3248|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 80
# Len Groceries:2
# n = 2;
# groceries = [|1980,42,48,180,147,2640|1650,75,270,30,116,2282|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 81
# Len Groceries:2
# n = 2;
# groceries = [|2750,140,30,230,132,2715|3078,42,336,174,67,1717|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 82
# Len Groceries:2
# n = 2;
# groceries = [|2275,21,217,147,164,3157|1092,42,42,84,171,1998|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 83
# Len Groceries:2
# n = 2;
# groceries = [|3321,108,378,153,129,1070|3568,112,456,144,183,1719|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 84
# Len Groceries:2
# n = 2;
# groceries = [|1160,10,145,60,79,2657|3070,140,560,30,148,3858|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 85
# Len Groceries:2
# n = 2;
# groceries = [|4428,27,594,216,177,1399|2185,55,210,125,129,1815|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 86
# Len Groceries:2
# n = 2;
# groceries = [|2280,48,306,96,103,3977|2390,140,210,110,160,2595|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 87
# Len Groceries:2
# n = 2;
# groceries = [|1810,20,50,170,174,3712|770,49,49,42,67,1250|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 88
# Len Groceries:2
# n = 2;
# groceries = [|2910,60,240,190,71,2740|2605,45,325,125,67,1850|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 89
# Len Groceries:2
# n = 2;
# groceries = [|2336,48,464,32,196,3533|2165,55,295,85,103,3495|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 90
# Len Groceries:2
# n = 2;
# groceries = [|2324,7,133,196,167,923|1760,40,220,80,91,3728|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 91
# Len Groceries:2
# n = 2;
# groceries = [|1080,120,60,40,181,1128|3510,140,310,190,57,2445|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 92
# Len Groceries:2
# n = 2;
# groceries = [|2010,42,366,42,152,1996|2064,90,318,48,55,3574|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 93
# Len Groceries:2
# n = 2;
# groceries = [|1464,48,48,120,82,2029|2086,105,133,126,179,3441|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 94
# Len Groceries:2
# n = 2;
# groceries = [|3940,10,480,220,73,1908|3820,110,530,140,75,1762|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 95
# Len Groceries:2
# n = 2;
# groceries = [|1790,40,70,150,170,3759|5184,63,666,252,99,3906|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 96
# Len Groceries:2
# n = 2;
# groceries = [|3492,126,180,252,100,998|876,78,60,36,174,1405|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 97
# Len Groceries:2
# n = 2;
# groceries = [|2940,120,390,100,179,1688|2016,63,189,112,110,3840|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 98
# Len Groceries:2
# n = 2;
# groceries = [|1233,45,162,45,89,1028|5570,100,730,250,163,3539|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 99
# Len Groceries:2
# n = 2;
# groceries = [|2970,90,369,126,121,3792|4240,120,472,208,132,3310|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 100
# Len Groceries:2
# n = 2;
# groceries = [|2187,117,369,27,53,2165|1555,10,75,135,52,1656|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 101
# Len Groceries:2
# n = 2;
# groceries = [|2480,40,40,240,101,2865|1135,30,175,35,61,2790|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 102
# Len Groceries:2
# n = 2;
# groceries = [|4347,36,666,171,200,945|3156,72,420,132,182,2337|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 103
# Len Groceries:2
# n = 2;
# groceries = [|1967,28,259,91,99,2205|3320,8,480,152,125,2394|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 104
# Len Groceries:2
# n = 2;
# groceries = [|2576,7,448,84,106,2866|3690,130,410,170,113,1928|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 105
# Len Groceries:2
# n = 2;
# groceries = [|2565,63,153,189,122,2275|1615,15,265,55,52,3730|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 106
# Len Groceries:2
# n = 2;
# groceries = [|2176,8,320,96,107,2062|896,70,91,28,118,1904|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 107
# Len Groceries:2
# n = 2;
# groceries = [|5420,130,640,260,54,3711|1320,96,72,72,114,2600|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 108
# Len Groceries:2
# n = 2;
# groceries = [|2682,63,324,126,56,1334|3576,56,352,216,155,1362|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 109
# Len Groceries:2
# n = 2;
# groceries = [|1495,15,280,35,61,3262|2916,27,378,144,58,3174|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 110
# Len Groceries:2
# n = 2;
# groceries = [|1672,72,328,8,80,2699|2821,91,189,189,78,2625|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 111
# Len Groceries:2
# n = 2;
# groceries = [|1560,55,200,60,177,3895|2044,63,385,28,77,2210|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 112
# Len Groceries:2
# n = 2;
# groceries = [|1446,18,276,30,163,3683|3789,90,594,117,84,2042|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 113
# Len Groceries:2
# n = 2;
# groceries = [|1055,50,135,35,171,1473|3249,72,396,153,175,1655|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 114
# Len Groceries:2
# n = 2;
# groceries = [|2046,60,384,30,156,1692|1992,18,102,168,95,1919|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 115
# Len Groceries:2
# n = 2;
# groceries = [|1800,42,84,144,188,3814|1704,40,152,104,163,1561|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 116
# Len Groceries:2
# n = 2;
# groceries = [|1470,45,165,70,152,3031|2037,7,455,21,189,2381|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 117
# Len Groceries:2
# n = 2;
# groceries = [|2720,35,375,120,72,2537|3206,63,266,210,159,3118|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 118
# Len Groceries:2
# n = 2;
# groceries = [|1624,64,72,120,103,1816|702,24,84,30,70,1584|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 119
# Len Groceries:2
# n = 2;
# groceries = [|3450,100,470,130,110,3613|1722,35,301,42,66,1533|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 120
# Len Groceries:2
# n = 2;
# groceries = [|873,99,99,9,137,2698|1744,88,312,16,155,2358|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 121
# Len Groceries:2
# n = 2;
# groceries = [|3320,150,50,280,50,1110|3750,140,190,270,105,1700|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 122
# Len Groceries:2
# n = 2;
# groceries = [|2586,72,264,138,85,3878|3084,12,354,180,71,2728|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 123
# Len Groceries:2
# n = 2;
# groceries = [|1104,12,102,72,200,2810|2765,65,345,125,96,3630|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 124
# Len Groceries:2
# n = 2;
# groceries = [|3820,40,240,300,82,3955|1555,55,210,55,173,1248|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 125
# Len Groceries:2
# n = 2;
# groceries = [|2556,60,444,60,143,2103|3112,40,360,168,86,820|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 126
# Len Groceries:2
# n = 2;
# groceries = [|1420,20,245,40,173,1858|3321,45,360,189,86,2839|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 127
# Len Groceries:2
# n = 2;
# groceries = [|1764,18,288,60,82,1653|2952,40,464,104,153,1272|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 128
# Len Groceries:2
# n = 2;
# groceries = [|3130,30,100,290,122,3575|3672,54,297,252,70,2410|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 129
# Len Groceries:2
# n = 2;
# groceries = [|2610,117,9,234,108,2959|2320,32,8,240,185,3081|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 130
# Len Groceries:2
# n = 2;
# groceries = [|2808,12,366,144,175,2224|2712,88,464,56,55,3612|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 131
# Len Groceries:2
# n = 2;
# groceries = [|1398,12,162,78,176,3312|2639,28,175,203,125,1436|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 132
# Len Groceries:2
# n = 2;
# groceries = [|1795,15,175,115,151,3467|1862,63,308,42,117,2682|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 133
# Len Groceries:2
# n = 2;
# groceries = [|2682,24,444,90,167,2783|725,70,10,45,145,3381|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 134
# Len Groceries:2
# n = 2;
# groceries = [|3325,63,343,189,141,2162|822,42,96,30,145,1868|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 135
# Len Groceries:2
# n = 2;
# groceries = [|2191,42,364,63,67,2040|3544,16,600,120,51,1726|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 136
# Len Groceries:2
# n = 2;
# groceries = [|1328,48,176,48,159,3225|2544,64,32,240,93,3947|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 137
# Len Groceries:2
# n = 2;
# groceries = [|2058,24,450,18,150,3350|1145,50,225,5,196,2335|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 138
# Len Groceries:2
# n = 2;
# groceries = [|3744,54,477,180,55,3580|1750,70,75,130,187,998|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 139
# Len Groceries:2
# n = 2;
# groceries = [|4203,108,558,171,123,1652|1998,72,36,174,120,1345|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 140
# Len Groceries:2
# n = 2;
# groceries = [|3790,150,370,190,120,1766|2709,77,175,189,61,2511|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 141
# Len Groceries:2
# n = 2;
# groceries = [|4210,40,720,130,118,1824|1320,36,24,120,177,3440|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 142
# Len Groceries:2
# n = 2;
# groceries = [|2608,56,200,176,184,3888|3312,9,576,108,173,1545|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 143
# Len Groceries:2
# n = 2;
# groceries = [|3536,120,296,208,69,1863|3519,81,576,99,140,1500|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 144
# Len Groceries:2
# n = 2;
# groceries = [|4023,36,423,243,181,2225|3069,36,549,81,186,3728|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 145
# Len Groceries:2
# n = 2;
# groceries = [|3255,49,371,175,176,2369|910,30,175,10,142,2863|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 146
# Len Groceries:2
# n = 2;
# groceries = [|1728,36,126,120,92,1150|4491,99,477,243,199,1421|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 147
# Len Groceries:2
# n = 2;
# groceries = [|1374,12,318,6,158,3400|462,12,90,6,122,3896|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 148
# Len Groceries:2
# n = 2;
# groceries = [|1806,18,96,150,182,2676|3700,80,710,60,139,2032|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 149
# Len Groceries:2
# n = 2;
# groceries = [|2352,120,432,16,125,2157|2637,63,414,81,125,1895|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 150
# Len Groceries:2
# n = 2;
# groceries = [|2336,72,296,96,52,3433|2727,126,90,207,149,2518|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 151
# Len Groceries:2
# n = 2;
# groceries = [|2630,20,390,110,144,2786|2392,24,376,88,82,3117|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 152
# Len Groceries:2
# n = 2;
# groceries = [|2400,20,265,140,145,3581|2816,72,200,192,84,1405|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 153
# Len Groceries:2
# n = 2;
# groceries = [|2637,18,378,117,169,2853|539,28,91,7,113,2086|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 154
# Len Groceries:2
# n = 2;
# groceries = [|864,99,36,36,128,3404|2198,7,385,70,146,1144|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 155
# Len Groceries:2
# n = 2;
# groceries = [|2023,21,217,119,153,3791|2828,42,476,84,68,3173|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 156
# Len Groceries:2
# n = 2;
# groceries = [|2334,54,246,126,178,2471|2349,36,288,117,53,2408|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 157
# Len Groceries:2
# n = 2;
# groceries = [|1675,70,90,115,124,3830|1626,36,6,162,108,1049|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 158
# Len Groceries:2
# n = 2;
# groceries = [|2360,70,160,160,109,3797|3204,9,468,144,168,3471|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 159
# Len Groceries:2
# n = 2;
# groceries = [|294,14,28,14,155,2386|2050,15,160,150,78,3321|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 160
# Len Groceries:2
# n = 2;
# groceries = [|1645,7,42,161,181,2060|2745,117,387,81,66,3857|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 161
# Len Groceries:2
# n = 2;
# groceries = [|3416,14,399,196,164,1245|2250,78,444,18,82,3347|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 162
# Len Groceries:2
# n = 2;
# groceries = [|2310,91,77,182,123,943|2952,6,354,168,199,2233|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 163
# Len Groceries:2
# n = 2;
# groceries = [|1010,70,115,30,195,2784|2238,18,366,78,64,3660|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 164
# Len Groceries:2
# n = 2;
# groceries = [|2304,117,216,108,113,3872|2870,140,510,30,125,2399|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 165
# Len Groceries:2
# n = 2;
# groceries = [|3136,96,400,128,101,2532|1872,42,318,48,164,3917|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 166
# Len Groceries:2
# n = 2;
# groceries = [|2620,150,190,140,91,1157|840,30,135,20,97,2033|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 167
# Len Groceries:2
# n = 2;
# groceries = [|1768,32,392,8,93,1461|2943,90,180,207,193,2759|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 168
# Len Groceries:2
# n = 2;
# groceries = [|1896,72,312,40,120,2020|1380,72,138,60,143,2087|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 169
# Len Groceries:2
# n = 2;
# groceries = [|1980,70,110,140,151,3681|2640,54,282,144,166,2727|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 170
# Len Groceries:2
# n = 2;
# groceries = [|3550,140,410,150,171,942|1302,21,273,14,61,3922|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 171
# Len Groceries:2
# n = 2;
# groceries = [|3018,84,360,138,130,1218|2170,75,220,110,129,3031|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 172
# Len Groceries:2
# n = 2;
# groceries = [|1630,30,130,110,125,2563|1925,56,189,105,67,1333|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 173
# Len Groceries:2
# n = 2;
# groceries = [|848,64,112,16,108,3210|2800,8,224,208,69,2980|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 174
# Len Groceries:2
# n = 2;
# groceries = [|1421,21,287,21,152,3517|1400,80,180,40,130,2703|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 175
# Len Groceries:2
# n = 2;
# groceries = [|4024,96,568,152,195,2809|1864,40,120,136,174,994|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 176
# Len Groceries:2
# n = 2;
# groceries = [|3260,120,200,220,116,2745|1863,63,180,99,193,2155|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 177
# Len Groceries:2
# n = 2;
# groceries = [|1220,10,70,100,121,2473|1935,126,54,135,161,1952|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 178
# Len Groceries:2
# n = 2;
# groceries = [|1450,40,120,90,156,2765|2088,18,450,24,53,2429|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 179
# Len Groceries:2
# n = 2;
# groceries = [|1805,15,245,85,194,1611|4208,24,488,240,160,1789|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 180
# Len Groceries:2
# n = 2;
# groceries = [|1450,15,280,30,171,1785|2660,70,280,140,152,1947|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 181
# Len Groceries:2
# n = 2;
# groceries = [|3470,150,290,190,64,1844|4208,72,584,176,125,2754|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 182
# Len Groceries:2
# n = 2;
# groceries = [|3120,48,480,112,175,1657|2667,105,294,119,163,998|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 183
# Len Groceries:2
# n = 2;
# groceries = [|2493,45,72,225,140,1121|2928,32,304,176,164,1749|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 184
# Len Groceries:2
# n = 2;
# groceries = [|2925,99,450,81,134,3161|2156,77,336,56,65,2699|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 185
# Len Groceries:2
# n = 2;
# groceries = [|2324,21,308,112,188,3237|3285,63,414,153,65,3778|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 186
# Len Groceries:2
# n = 2;
# groceries = [|2696,80,72,232,135,3360|1248,48,48,96,149,3832|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 187
# Len Groceries:2
# n = 2;
# groceries = [|1638,21,168,98,113,3434|792,56,16,56,72,1819|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 188
# Len Groceries:2
# n = 2;
# groceries = [|2443,28,378,91,195,3488|2780,100,100,220,87,2884|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 189
# Len Groceries:2
# n = 2;
# groceries = [|2676,72,300,132,183,2155|2590,14,224,182,68,3404|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 190
# Len Groceries:2
# n = 2;
# groceries = [|848,80,96,16,196,3374|2994,48,390,138,81,1140|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 191
# Len Groceries:2
# n = 2;
# groceries = [|780,45,60,40,130,1842|2088,72,144,136,66,1691|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 192
# Len Groceries:2
# n = 2;
# groceries = [|2660,30,320,140,192,3334|2274,12,246,138,177,3232|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 193
# Len Groceries:2
# n = 2;
# groceries = [|1358,77,42,98,54,3873|2205,36,9,225,141,1058|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 194
# Len Groceries:2
# n = 2;
# groceries = [|2655,18,585,27,62,983|2646,28,476,70,77,861|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 195
# Len Groceries:2
# n = 2;
# groceries = [|3900,50,430,220,149,1007|1098,24,210,18,96,2713|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 196
# Len Groceries:2
# n = 2;
# groceries = [|1240,35,95,80,135,2553|1960,60,250,80,195,1018|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 197
# Len Groceries:2
# n = 2;
# groceries = [|3409,56,497,133,64,3545|1928,24,440,8,185,1268|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 198
# Len Groceries:2
# n = 2;
# groceries = [|1545,35,340,5,94,1143|438,18,78,6,72,1424|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 199
# Len Groceries:2
# n = 2;
# groceries = [|2716,14,413,112,56,1110|1834,70,357,14,108,1213|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 200
# Len Groceries:2
# n = 2;
# groceries = [|1716,24,216,84,56,3979|5100,30,750,220,199,2005|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 201
# Len Groceries:2
# n = 2;
# groceries = [|3346,49,441,154,193,3913|2152,48,40,200,160,3053|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 202
# Len Groceries:2
# n = 2;
# groceries = [|1008,72,99,36,163,2311|1045,15,190,25,183,1520|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 203
# Len Groceries:2
# n = 2;
# groceries = [|2618,14,294,154,152,1897|1460,40,190,60,151,3390|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 204
# Len Groceries:2
# n = 2;
# groceries = [|3429,72,522,117,174,3948|3357,126,450,117,114,2834|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 205
# Len Groceries:2
# n = 2;
# groceries = [|3024,54,297,180,190,1208|2904,8,232,216,144,2307|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 206
# Len Groceries:2
# n = 2;
# groceries = [|3064,64,432,120,143,2638|4284,81,504,216,186,2607|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 207
# Len Groceries:2
# n = 2;
# groceries = [|2691,36,495,63,109,3426|2040,55,320,60,181,1152|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 208
# Len Groceries:2
# n = 2;
# groceries = [|1644,24,252,60,200,1918|2128,72,424,16,96,830|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 209
# Len Groceries:2
# n = 2;
# groceries = [|2376,9,99,216,125,2002|2682,72,396,90,92,3672|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 210
# Len Groceries:2
# n = 2;
# groceries = [|3300,140,190,220,86,2810|1525,10,180,85,118,2657|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 211
# Len Groceries:2
# n = 2;
# groceries = [|3980,110,750,60,167,2790|975,15,195,15,81,1454|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 212
# Len Groceries:2
# n = 2;
# groceries = [|1442,49,280,14,196,1544|3438,27,630,90,127,1863|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 213
# Len Groceries:2
# n = 2;
# groceries = [|2448,54,396,72,99,1910|1856,32,72,160,111,3923|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 214
# Len Groceries:2
# n = 2;
# groceries = [|2400,30,210,160,172,3051|2034,36,432,18,199,3789|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 215
# Len Groceries:2
# n = 2;
# groceries = [|2160,48,240,112,66,3380|3670,130,360,190,61,2230|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 216
# Len Groceries:2
# n = 2;
# groceries = [|2646,54,270,150,188,2443|2312,88,184,136,64,2689|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 217
# Len Groceries:2
# n = 2;
# groceries = [|5480,90,740,240,66,2967|516,42,6,36,66,1834|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 218
# Len Groceries:2
# n = 2;
# groceries = [|2024,32,24,200,170,3903|1880,25,220,100,114,2314|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 219
# Len Groceries:2
# n = 2;
# groceries = [|3910,140,680,70,192,1548|3010,50,230,210,137,2711|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 220
# Len Groceries:2
# n = 2;
# groceries = [|2970,120,240,170,182,1843|4072,40,528,200,140,3739|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 221
# Len Groceries:2
# n = 2;
# groceries = [|3759,49,434,203,105,3051|1792,104,128,96,52,1318|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 222
# Len Groceries:2
# n = 2;
# groceries = [|3465,135,549,81,78,3602|1687,70,21,147,122,3553|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 223
# Len Groceries:2
# n = 2;
# groceries = [|2115,54,9,207,66,2402|3144,64,416,136,162,1611|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 224
# Len Groceries:2
# n = 2;
# groceries = [|4050,36,612,162,56,2607|2070,84,420,6,160,2592|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 225
# Len Groceries:2
# n = 2;
# groceries = [|2384,16,328,112,96,2056|1055,40,100,55,177,1596|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 226
# Len Groceries:2
# n = 2;
# groceries = [|2338,14,287,126,142,3557|2364,66,390,60,142,1733|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 227
# Len Groceries:2
# n = 2;
# groceries = [|1998,78,30,174,87,2940|2737,105,280,133,164,3289|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 228
# Len Groceries:2
# n = 2;
# groceries = [|2430,15,300,130,183,3639|1704,12,198,96,137,3330|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 229
# Len Groceries:2
# n = 2;
# groceries = [|2696,120,464,40,171,1475|2412,135,306,72,195,2955|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 230
# Len Groceries:2
# n = 2;
# groceries = [|2088,90,27,180,126,1983|2240,150,230,80,145,3189|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 231
# Len Groceries:2
# n = 2;
# groceries = [|5130,63,612,270,193,3038|3031,35,518,91,105,2486|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 232
# Len Groceries:2
# n = 2;
# groceries = [|2565,108,513,9,199,3468|1750,77,140,98,83,2224|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 233
# Len Groceries:2
# n = 2;
# groceries = [|1800,104,256,40,58,2735|1080,18,198,24,80,2882|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 234
# Len Groceries:2
# n = 2;
# groceries = [|3350,140,90,270,190,1085|2765,40,370,125,160,1345|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 235
# Len Groceries:2
# n = 2;
# groceries = [|585,10,125,5,180,3519|1956,66,342,36,164,1675|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 236
# Len Groceries:2
# n = 2;
# groceries = [|1890,60,48,162,196,2119|1890,30,240,90,176,3767|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 237
# Len Groceries:2
# n = 2;
# groceries = [|1005,15,180,25,146,2163|3288,112,512,88,78,2484|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 238
# Len Groceries:2
# n = 2;
# groceries = [|1980,9,405,36,155,2733|2513,84,497,21,149,3639|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 239
# Len Groceries:2
# n = 2;
# groceries = [|2130,45,285,90,126,1792|2090,45,365,50,196,2011|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 240
# Len Groceries:2
# n = 2;
# groceries = [|3762,36,297,270,107,1136|3310,140,440,110,163,960|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 241
# Len Groceries:2
# n = 2;
# groceries = [|1720,110,140,80,69,3064|1448,88,40,104,140,1690|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 242
# Len Groceries:2
# n = 2;
# groceries = [|1685,45,230,65,193,1705|2720,112,424,64,86,1515|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 243
# Len Groceries:2
# n = 2;
# groceries = [|1253,84,182,21,80,2839|2170,15,280,110,65,2248|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 244
# Len Groceries:2
# n = 2;
# groceries = [|2058,91,77,154,110,3384|1278,12,186,54,150,2977|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 245
# Len Groceries:2
# n = 2;
# groceries = [|1275,15,45,115,122,1235|2590,28,399,98,199,2779|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 246
# Len Groceries:2
# n = 2;
# groceries = [|1086,24,72,78,138,1501|1870,70,60,150,79,2565|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 247
# Len Groceries:2
# n = 2;
# groceries = [|2360,55,310,100,83,3440|1746,78,210,66,167,2728|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 248
# Len Groceries:2
# n = 2;
# groceries = [|2016,6,444,24,70,2980|3180,120,630,20,200,3949|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 249
# Len Groceries:2
# n = 2;
# groceries = [|1136,40,208,16,173,1811|2562,60,378,90,197,1465|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 250
# Len Groceries:2
# n = 2;
# groceries = [|1304,104,168,24,133,3016|2592,48,330,120,116,3192|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 251
# Len Groceries:2
# n = 2;
# groceries = [|1086,6,144,54,97,3845|4900,50,590,260,53,2348|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 252
# Len Groceries:2
# n = 2;
# groceries = [|2250,36,243,126,110,3116|2784,84,342,120,96,3232|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 253
# Len Groceries:2
# n = 2;
# groceries = [|3144,24,456,136,149,901|2178,9,9,234,170,2830|];
# ...
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 415
# Len Groceries:2
# n = 2;
# groceries = [|4040,120,260,280,88,2234|1314,78,156,42,117,888|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 416
# Len Groceries:2
# n = 2;
# groceries = [|791,14,105,35,77,3465|3400,56,344,200,151,2215|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 417
# Len Groceries:2
# n = 2;
# groceries = [|525,25,5,45,133,2658|1988,14,42,196,186,2774|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 418
# Len Groceries:2
# n = 2;
# groceries = [|1855,14,182,119,92,3150|2352,35,175,168,198,2629|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 419
# Len Groceries:2
# n = 2;
# groceries = [|2020,130,60,140,54,1233|1570,40,150,90,129,1425|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 420
# Len Groceries:2
# n = 2;
# groceries = [|1687,77,203,63,154,836|1085,25,190,25,165,3619|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 421
# Len Groceries:2
# n = 2;
# groceries = [|1939,77,329,35,50,3142|4365,135,612,153,121,2343|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 422
# Len Groceries:2
# n = 2;
# groceries = [|1085,75,185,5,97,1041|2324,35,168,168,110,1708|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 423
# Len Groceries:2
# n = 2;
# groceries = [|2368,56,248,128,158,844|3708,117,486,144,152,2286|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 424
# Len Groceries:2
# n = 2;
# groceries = [|3186,135,378,126,194,1239|1705,15,85,145,115,2493|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 425
# Len Groceries:2
# n = 2;
# groceries = [|3645,81,405,189,127,991|3310,50,260,230,116,3163|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 426
# Len Groceries:2
# n = 2;
# groceries = [|1050,42,126,42,199,3377|810,50,130,10,155,3706|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 427
# Len Groceries:2
# n = 2;
# groceries = [|2401,49,252,133,151,2510|2464,105,70,196,155,3379|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 428
# Len Groceries:2
# n = 2;
# groceries = [|2470,10,90,230,189,1016|2496,60,402,72,171,2468|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 429
# Len Groceries:2
# n = 2;
# groceries = [|510,48,12,30,144,2337|2778,18,366,138,109,2013|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 430
# Len Groceries:2
# n = 2;
# groceries = [|636,12,66,36,117,2827|2930,30,365,150,54,2411|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 431
# Len Groceries:2
# n = 2;
# groceries = [|2200,88,192,120,176,912|2105,35,300,85,107,1490|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 432
# Len Groceries:2
# n = 2;
# groceries = [|3573,117,270,225,139,804|2289,56,91,189,69,2121|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 433
# Len Groceries:2
# n = 2;
# groceries = [|2628,6,354,132,85,3844|1192,24,184,40,176,831|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 434
# Len Groceries:2
# n = 2;
# groceries = [|915,55,5,75,76,2423|2889,9,369,153,169,3021|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 435
# Len Groceries:2
# n = 2;
# groceries = [|1422,18,108,102,104,1396|1560,54,228,48,151,3870|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 436
# Len Groceries:2
# n = 2;
# groceries = [|4120,100,390,240,124,964|1665,75,240,45,166,2471|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 437
# Len Groceries:2
# n = 2;
# groceries = [|3094,56,434,126,159,3225|2400,78,306,96,66,3876|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 438
# Len Groceries:2
# n = 2;
# groceries = [|1836,48,384,12,148,952|2070,36,279,90,150,3807|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 439
# Len Groceries:2
# n = 2;
# groceries = [|2723,35,441,91,173,3549|4900,30,610,260,120,3456|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 440
# Len Groceries:2
# n = 2;
# groceries = [|3896,96,464,184,194,2343|2030,70,100,150,195,3871|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 441
# Len Groceries:2
# n = 2;
# groceries = [|4644,72,603,216,125,3864|2070,72,405,18,184,975|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 442
# Len Groceries:2
# n = 2;
# groceries = [|1100,15,125,60,100,3955|4560,30,660,200,198,2044|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 443
# Len Groceries:2
# n = 2;
# groceries = [|1494,54,36,126,71,1767|3618,36,423,198,80,1907|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 444
# Len Groceries:2
# n = 2;
# groceries = [|2244,42,438,36,91,3483|4800,120,576,224,67,2115|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 445
# Len Groceries:2
# n = 2;
# groceries = [|2940,80,520,60,54,3706|2835,27,135,243,86,2728|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 446
# Len Groceries:2
# n = 2;
# groceries = [|2616,54,330,120,152,1176|1017,117,36,45,114,3437|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 447
# Len Groceries:2
# n = 2;
# groceries = [|1350,126,90,54,112,2602|2835,126,360,99,189,3476|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 448
# Len Groceries:2
# n = 2;
# groceries = [|1168,32,8,112,191,1586|880,90,40,40,105,2495|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 449
# Len Groceries:2
# n = 2;
# groceries = [|2460,90,480,20,122,3470|3200,150,560,40,175,2251|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 450
# Len Groceries:2
# n = 2;
# groceries = [|4128,48,552,192,132,1086|3570,70,260,250,184,3025|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 451
# Len Groceries:2
# n = 2;
# groceries = [|1810,40,390,10,112,2097|2425,40,375,85,153,851|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 452
# Len Groceries:2
# n = 2;
# groceries = [|2760,78,450,72,160,1928|2065,28,189,133,66,2443|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 453
# Len Groceries:2
# n = 2;
# groceries = [|2950,30,370,150,199,1260|3760,60,610,120,119,1734|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 454
# Len Groceries:2
# n = 2;
# groceries = [|1835,55,370,15,135,3322|1100,10,130,60,51,1443|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 455
# Len Groceries:2
# n = 2;
# groceries = [|1736,70,112,112,117,2291|3213,108,432,117,151,3549|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 456
# Len Groceries:2
# n = 2;
# groceries = [|3645,99,630,81,171,1567|1185,70,35,85,138,882|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 457
# Len Groceries:2
# n = 2;
# groceries = [|1535,25,280,35,93,875|3600,70,740,40,129,2204|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 458
# Len Groceries:2
# n = 2;
# groceries = [|3910,70,660,110,119,1987|2172,24,222,132,126,3463|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 459
# Len Groceries:2
# n = 2;
# groceries = [|2020,5,320,80,173,3424|1405,30,175,65,174,2800|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 460
# Len Groceries:2
# n = 2;
# groceries = [|3321,108,216,225,197,1434|3120,10,590,80,108,3733|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 461
# Len Groceries:2
# n = 2;
# groceries = [|2115,50,310,75,53,3683|693,91,35,21,83,3000|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 462
# Len Groceries:2
# n = 2;
# groceries = [|415,10,60,15,82,1806|942,24,36,78,145,3492|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 463
# Len Groceries:2
# n = 2;
# groceries = [|2919,35,490,91,123,2129|2261,77,126,161,115,1231|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 464
# Len Groceries:2
# n = 2;
# groceries = [|2565,9,369,117,152,1106|2382,36,168,174,106,1766|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 465
# Len Groceries:2
# n = 2;
# groceries = [|4248,9,648,180,53,2513|3232,104,416,128,67,3622|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 466
# Len Groceries:2
# n = 2;
# groceries = [|2530,30,130,210,196,2749|1264,96,112,48,173,2580|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 467
# Len Groceries:2
# n = 2;
# groceries = [|4490,80,660,170,78,3334|1710,20,340,30,193,3013|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 468
# Len Groceries:2
# n = 2;
# groceries = [|4840,150,610,200,177,1737|1560,54,282,24,152,1941|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 469
# Len Groceries:2
# n = 2;
# groceries = [|2148,42,414,36,83,1970|4365,36,468,261,137,3350|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 470
# Len Groceries:2
# n = 2;
# groceries = [|623,35,42,35,50,2162|2630,120,470,30,117,3499|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 471
# Len Groceries:2
# n = 2;
# groceries = [|910,10,15,90,123,2652|3423,21,441,175,88,926|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 472
# Len Groceries:2
# n = 2;
# groceries = [|1476,90,90,84,109,2722|1350,9,126,90,69,2263|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 473
# Len Groceries:2
# n = 2;
# groceries = [|2430,18,144,198,73,1733|805,35,110,25,129,1101|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 474
# Len Groceries:2
# n = 2;
# groceries = [|1356,84,174,36,142,3832|1998,60,372,30,158,3737|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 475
# Len Groceries:2
# n = 2;
# groceries = [|2592,63,423,72,67,2836|2598,24,396,102,193,3718|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 476
# Len Groceries:2
# n = 2;
# groceries = [|4080,112,368,240,200,2678|2000,72,320,48,99,999|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 477
# Len Groceries:2
# n = 2;
# groceries = [|2233,14,182,161,108,1394|1407,105,168,35,120,3726|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 478
# Len Groceries:2
# n = 2;
# groceries = [|1375,50,215,35,139,2312|1825,5,125,145,180,3576|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 479
# Len Groceries:2
# n = 2;
# groceries = [|820,20,50,60,144,1126|3460,30,250,260,50,2822|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 480
# Len Groceries:2
# n = 2;
# groceries = [|1305,15,300,5,189,1689|1848,60,348,24,73,2075|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 481
# Len Groceries:2
# n = 2;
# groceries = [|4208,8,504,240,80,3669|2150,150,320,30,55,1413|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 482
# Len Groceries:2
# n = 2;
# groceries = [|3450,70,680,50,70,3939|2395,65,230,135,132,3970|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 483
# Len Groceries:2
# n = 2;
# groceries = [|2704,56,512,48,188,3104|2952,45,126,252,72,2463|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 484
# Len Groceries:2
# n = 2;
# groceries = [|1715,30,140,115,176,825|2200,60,355,60,54,3969|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 485
# Len Groceries:2
# n = 2;
# groceries = [|3227,91,511,91,131,1841|4158,90,504,198,57,1015|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 486
# Len Groceries:2
# n = 2;
# groceries = [|4509,126,657,153,197,3807|4648,80,560,232,196,2636|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 487
# Len Groceries:2
# n = 2;
# groceries = [|2340,10,80,220,118,1837|1376,40,88,96,113,3626|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 488
# Len Groceries:2
# n = 2;
# groceries = [|1800,81,207,72,153,2140|2808,32,400,120,157,975|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 489
# Len Groceries:2
# n = 2;
# groceries = [|2166,24,396,54,120,1183|1945,60,235,85,131,1082|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 490
# Len Groceries:2
# n = 2;
# groceries = [|1647,54,54,135,113,945|3250,110,680,10,149,2608|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 491
# Len Groceries:2
# n = 2;
# groceries = [|3636,27,396,216,80,1282|2718,45,189,198,58,2690|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 492
# Len Groceries:2
# n = 2;
# groceries = [|955,30,85,55,86,3959|2814,91,455,70,85,3930|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 493
# Len Groceries:2
# n = 2;
# groceries = [|4950,140,490,270,106,3339|2432,120,344,64,148,1658|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 494
# Len Groceries:2
# n = 2;
# groceries = [|2096,56,432,16,63,1785|2541,91,434,49,124,2158|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 495
# Len Groceries:2
# n = 2;
# groceries = [|2790,110,160,190,157,2871|2892,54,372,132,129,2956|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 496
# Len Groceries:2
# n = 2;
# groceries = [|4240,96,424,240,107,2936|5510,110,750,230,76,3945|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 497
# Len Groceries:2
# n = 2;
# groceries = [|2880,42,408,120,183,2152|3017,42,413,133,67,3928|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 498
# Len Groceries:2
# n = 2;
# groceries = [|2898,60,408,114,80,2070|1730,10,220,90,110,1482|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# Days = 4
# People = 4
# created: Instance 499
