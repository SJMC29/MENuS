# %% [markdown]
# # Generate instances

# %%
import random
import math
import numpy as np

days = random.randint(4, 6)
people = random.randint(4, 6)
minprot = 38*days*people
maxprot = int(46*days*people)    
mincar = 200*days*people
maxcar = int(200*days*people)    
minfat = 57*days*people
maxfat = int(62*days*people)

def printN(n):
    n = "n = " + str(n)    
    return n
def createProtein():
    quantity = 1*random.randint(5,10)    
    protein = random.randint(1, 30)*quantity
    carbohydrate = random.randint(1, 37)*quantity    
    fat = random.randint(1, 30)*quantity  
    product = ""
    product = product + str(protein) + "," + str(carbohydrate) + "," + str(fat) + "," + str(random.randint(50, 200)) + "," + str(random.randint(800, 4000)) + "|"    
    return product
def createCarbohydrate():
    quantity = 1*random.randint(5,10)    
    protein = random.randint(1, 15)*quantity
    carbohydrate = random.randint(1, 75)*quantity    
    fat = random.randint(1, 30)*quantity   
    product = ""
    product = product + str(protein) + "," + str(carbohydrate) + "," + str(fat) + "," + str(random.randint(50, 200)) + "," + str(random.randint(800, 4000)) + "|"    
    return product
def createFat():
    quantity = 1*random.randint(5,10)    
    protein = random.randint(1, 15)*quantity
    carbohydrate = random.randint(1, 37)*quantity    
    fat = random.randint(1, 80)*quantity  
    product = ""
    product = product + str(protein) + "," + str(carbohydrate) + "," + str(fat) + "," + str(random.randint(50, 200)) + "," + str(random.randint(800, 4000)) + "|"    
    return product
def createGroceries(n):
    longitud = 0    
    groceries = "[|"
    for i in range(0,math.floor(n/3)):      
        protein = createProtein()
        groceries = groceries + protein
        longitud = longitud + 1    
    for i in range(0,math.floor(n/3)):
        carbo = createCarbohydrate()
        groceries = groceries + carbo
        longitud = longitud + 1
    for i in range(0,math.floor(n/3)):
        fat = createFat()    
        groceries = groceries + fat
        longitud = longitud + 1    
    for i in range(n-longitud):
        carbo = createCarbohydrate()
        groceries = groceries + carbo       
        longitud = longitud + 1
    groceries = groceries + "]"
    return groceries
def printGroceries(n):
    groceries = "groceries = " + str(createGroceries(n))
    return groceries

def createRequirements():    #Redondear holgura < 2
    requirements = "[|" + str(minprot) + "," + str(maxprot) + \
                    "|" + str(mincar) + "," + str(maxcar) + \
                    "|" + str(minfat) + "," + str(maxfat) + "|]"
    return requirements
def printRequirements():    
    requirements = "requirements = " + str(createRequirements())
    return requirements

def createOffset():  
    offset = "[|" + str(int(minprot*.1)) + "," + str(int(maxprot*.2)) + \
             "|" + str(int(mincar*.5)) + "," + str(int(maxcar*.65)) + \
             "|" + str(int(minfat*.25)) + "," + str(int(maxfat*.35)) + "|]"
    return offset
def printOffset():
    offset = "offset = " + str(createOffset())
    return offset

def printBudget():
    budget = "budget = " + str(int(50000*days*1))
    return budget

def printVariety():
    variety = "variety = " + str(int(random.randint(1,44)))
    return variety

def createDZN(n): 
    groceries = printGroceries(n)
    dzn = printN(n) + ";\n" + printBudget() + ";\n" + groceries + ";\n" + printRequirements() + ";\n" + printOffset() + ";\n" + printVariety() + ";"   
    return(dzn)

# %%
def create_IL(n):
    for i in range(n):
        path = '../instances/'+str(i)+'.dzn'
        #print(model)
        with open(path, 'w', encoding='utf8') as file_object:
            file_object.write(createDZN(random.randint(1, 100)))
        print('created: Instance',i)

create_IL(500)
# Out:
# created: Instance 0
# created: Instance 1
# created: Instance 2
# created: Instance 3
# created: Instance 4
# created: Instance 5
# created: Instance 6
# created: Instance 7
# created: Instance 8
# created: Instance 9
# created: Instance 10
# created: Instance 11
# created: Instance 12
# created: Instance 13
# created: Instance 14
# created: Instance 15
# created: Instance 16
# created: Instance 17
# created: Instance 18
# created: Instance 19
# created: Instance 20
# created: Instance 21
# created: Instance 22
# created: Instance 23
# created: Instance 24
# created: Instance 25
# created: Instance 26
# created: Instance 27
# created: Instance 28
# created: Instance 29
# created: Instance 30
# created: Instance 31
# created: Instance 32
# created: Instance 33
# created: Instance 34
# created: Instance 35
# created: Instance 36
# created: Instance 37
# created: Instance 38
# created: Instance 39
# created: Instance 40
# created: Instance 41
# created: Instance 42
# created: Instance 43
# created: Instance 44
# created: Instance 45
# created: Instance 46
# created: Instance 47
# created: Instance 48
# created: Instance 49
# created: Instance 50
# created: Instance 51
# created: Instance 52
# created: Instance 53
# created: Instance 54
# created: Instance 55
# created: Instance 56
# created: Instance 57
# created: Instance 58
# created: Instance 59
# created: Instance 60
# created: Instance 61
# created: Instance 62
# created: Instance 63
# created: Instance 64
# created: Instance 65
# created: Instance 66
# created: Instance 67
# created: Instance 68
# created: Instance 69
# created: Instance 70
# created: Instance 71
# created: Instance 72
# created: Instance 73
# created: Instance 74
# created: Instance 75
# created: Instance 76
# created: Instance 77
# created: Instance 78
# created: Instance 79
# created: Instance 80
# created: Instance 81
# created: Instance 82
# created: Instance 83
# created: Instance 84
# created: Instance 85
# created: Instance 86
# created: Instance 87
# created: Instance 88
# created: Instance 89
# created: Instance 90
# created: Instance 91
# created: Instance 92
# created: Instance 93
# created: Instance 94
# created: Instance 95
# created: Instance 96
# created: Instance 97
# created: Instance 98
# created: Instance 99
# created: Instance 100
# created: Instance 101
# created: Instance 102
# created: Instance 103
# created: Instance 104
# created: Instance 105
# created: Instance 106
# created: Instance 107
# created: Instance 108
# created: Instance 109
# created: Instance 110
# created: Instance 111
# created: Instance 112
# created: Instance 113
# created: Instance 114
# created: Instance 115
# created: Instance 116
# created: Instance 117
# created: Instance 118
# created: Instance 119
# created: Instance 120
# created: Instance 121
# created: Instance 122
# created: Instance 123
# created: Instance 124
# created: Instance 125
# created: Instance 126
# created: Instance 127
# created: Instance 128
# created: Instance 129
# created: Instance 130
# created: Instance 131
# created: Instance 132
# created: Instance 133
# created: Instance 134
# created: Instance 135
# created: Instance 136
# created: Instance 137
# created: Instance 138
# created: Instance 139
# created: Instance 140
# created: Instance 141
# created: Instance 142
# created: Instance 143
# created: Instance 144
# created: Instance 145
# created: Instance 146
# created: Instance 147
# created: Instance 148
# created: Instance 149
# created: Instance 150
# created: Instance 151
# created: Instance 152
# created: Instance 153
# created: Instance 154
# created: Instance 155
# created: Instance 156
# created: Instance 157
# created: Instance 158
# created: Instance 159
# created: Instance 160
# created: Instance 161
# created: Instance 162
# created: Instance 163
# created: Instance 164
# created: Instance 165
# created: Instance 166
# created: Instance 167
# created: Instance 168
# created: Instance 169
# created: Instance 170
# created: Instance 171
# created: Instance 172
# created: Instance 173
# created: Instance 174
# created: Instance 175
# created: Instance 176
# created: Instance 177
# created: Instance 178
# created: Instance 179
# created: Instance 180
# created: Instance 181
# created: Instance 182
# created: Instance 183
# created: Instance 184
# created: Instance 185
# created: Instance 186
# created: Instance 187
# created: Instance 188
# created: Instance 189
# created: Instance 190
# created: Instance 191
# created: Instance 192
# created: Instance 193
# created: Instance 194
# created: Instance 195
# created: Instance 196
# created: Instance 197
# created: Instance 198
# created: Instance 199
# created: Instance 200
# created: Instance 201
# created: Instance 202
# created: Instance 203
# created: Instance 204
# created: Instance 205
# created: Instance 206
# created: Instance 207
# created: Instance 208
# created: Instance 209
# created: Instance 210
# created: Instance 211
# created: Instance 212
# created: Instance 213
# created: Instance 214
# created: Instance 215
# created: Instance 216
# created: Instance 217
# created: Instance 218
# created: Instance 219
# created: Instance 220
# created: Instance 221
# created: Instance 222
# created: Instance 223
# created: Instance 224
# created: Instance 225
# created: Instance 226
# created: Instance 227
# created: Instance 228
# created: Instance 229
# created: Instance 230
# created: Instance 231
# created: Instance 232
# created: Instance 233
# created: Instance 234
# created: Instance 235
# created: Instance 236
# created: Instance 237
# created: Instance 238
# created: Instance 239
# created: Instance 240
# created: Instance 241
# created: Instance 242
# created: Instance 243
# created: Instance 244
# created: Instance 245
# created: Instance 246
# created: Instance 247
# created: Instance 248
# created: Instance 249
# created: Instance 250
# created: Instance 251
# created: Instance 252
# created: Instance 253
# created: Instance 254
# created: Instance 255
# created: Instance 256
# created: Instance 257
# created: Instance 258
# created: Instance 259
# created: Instance 260
# created: Instance 261
# created: Instance 262
# created: Instance 263
# created: Instance 264
# created: Instance 265
# created: Instance 266
# created: Instance 267
# created: Instance 268
# created: Instance 269
# created: Instance 270
# created: Instance 271
# created: Instance 272
# created: Instance 273
# created: Instance 274
# created: Instance 275
# created: Instance 276
# created: Instance 277
# created: Instance 278
# created: Instance 279
# created: Instance 280
# created: Instance 281
# created: Instance 282
# created: Instance 283
# created: Instance 284
# created: Instance 285
# created: Instance 286
# created: Instance 287
# created: Instance 288
# created: Instance 289
# created: Instance 290
# created: Instance 291
# created: Instance 292
# created: Instance 293
# created: Instance 294
# created: Instance 295
# created: Instance 296
# created: Instance 297
# created: Instance 298
# created: Instance 299
# created: Instance 300
# created: Instance 301
# created: Instance 302
# created: Instance 303
# created: Instance 304
# created: Instance 305
# created: Instance 306
# created: Instance 307
# created: Instance 308
# created: Instance 309
# created: Instance 310
# created: Instance 311
# created: Instance 312
# created: Instance 313
# created: Instance 314
# created: Instance 315
# created: Instance 316
# created: Instance 317
# created: Instance 318
# created: Instance 319
# created: Instance 320
# created: Instance 321
# created: Instance 322
# created: Instance 323
# created: Instance 324
# created: Instance 325
# created: Instance 326
# created: Instance 327
# created: Instance 328
# created: Instance 329
# created: Instance 330
# created: Instance 331
# created: Instance 332
# created: Instance 333
# created: Instance 334
# created: Instance 335
# created: Instance 336
# created: Instance 337
# created: Instance 338
# created: Instance 339
# created: Instance 340
# created: Instance 341
# created: Instance 342
# created: Instance 343
# created: Instance 344
# created: Instance 345
# created: Instance 346
# created: Instance 347
# created: Instance 348
# created: Instance 349
# created: Instance 350
# created: Instance 351
# created: Instance 352
# created: Instance 353
# created: Instance 354
# created: Instance 355
# created: Instance 356
# created: Instance 357
# created: Instance 358
# created: Instance 359
# created: Instance 360
# created: Instance 361
# created: Instance 362
# created: Instance 363
# created: Instance 364
# created: Instance 365
# created: Instance 366
# created: Instance 367
# created: Instance 368
# created: Instance 369
# created: Instance 370
# created: Instance 371
# created: Instance 372
# created: Instance 373
# created: Instance 374
# created: Instance 375
# created: Instance 376
# created: Instance 377
# created: Instance 378
# created: Instance 379
# created: Instance 380
# created: Instance 381
# created: Instance 382
# created: Instance 383
# created: Instance 384
# created: Instance 385
# created: Instance 386
# created: Instance 387
# created: Instance 388
# created: Instance 389
# created: Instance 390
# created: Instance 391
# created: Instance 392
# created: Instance 393
# created: Instance 394
# created: Instance 395
# created: Instance 396
# created: Instance 397
# created: Instance 398
# created: Instance 399
# created: Instance 400
# created: Instance 401
# created: Instance 402
# created: Instance 403
# created: Instance 404
# created: Instance 405
# created: Instance 406
# created: Instance 407
# created: Instance 408
# created: Instance 409
# created: Instance 410
# created: Instance 411
# created: Instance 412
# created: Instance 413
# created: Instance 414
# created: Instance 415
# created: Instance 416
# created: Instance 417
# created: Instance 418
# created: Instance 419
# created: Instance 420
# created: Instance 421
# created: Instance 422
# created: Instance 423
# created: Instance 424
# created: Instance 425
# created: Instance 426
# created: Instance 427
# created: Instance 428
# created: Instance 429
# created: Instance 430
# created: Instance 431
# created: Instance 432
# created: Instance 433
# created: Instance 434
# created: Instance 435
# created: Instance 436
# created: Instance 437
# created: Instance 438
# created: Instance 439
# created: Instance 440
# created: Instance 441
# created: Instance 442
# created: Instance 443
# created: Instance 444
# created: Instance 445
# created: Instance 446
# created: Instance 447
# created: Instance 448
# created: Instance 449
# created: Instance 450
# created: Instance 451
# created: Instance 452
# created: Instance 453
# created: Instance 454
# created: Instance 455
# created: Instance 456
# created: Instance 457
# created: Instance 458
# created: Instance 459
# created: Instance 460
# created: Instance 461
# created: Instance 462
# created: Instance 463
# created: Instance 464
# created: Instance 465
# created: Instance 466
# created: Instance 467
# created: Instance 468
# created: Instance 469
# created: Instance 470
# created: Instance 471
# created: Instance 472
# created: Instance 473
# created: Instance 474
# created: Instance 475
# created: Instance 476
# created: Instance 477
# created: Instance 478
# created: Instance 479
# created: Instance 480
# created: Instance 481
# created: Instance 482
# created: Instance 483
# created: Instance 484
# created: Instance 485
# created: Instance 486
# created: Instance 487
# created: Instance 488
# created: Instance 489
# created: Instance 490
# created: Instance 491
# created: Instance 492
# created: Instance 493
# created: Instance 494
# created: Instance 495
# created: Instance 496
# created: Instance 497
# created: Instance 498
# created: Instance 499
