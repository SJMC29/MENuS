# %% [markdown]
# # Generate instances

# %%
import random
import math
def printN(n):
    n = "n = " + str(n)    
    return n
def createProtein():
    quantity = 1*random.randint(5,10)    
    protein = random.randint(1, 30)*quantity
    carbohydrate = random.randint(1, 37)*quantity    
    fat = random.randint(1, 30)*quantity
    calories = protein*4 + carbohydrate*4 + fat*9    
    product = ""
    product = product + str(calories) + "," + str(protein) + "," + str(carbohydrate) + "," + str(fat) + "," + str(random.randint(50, 200)) + "," + str(random.randint(800, 4000)) + "|"    
    return product
def createCarbohydrate():
    quantity = 1*random.randint(5,10)    
    protein = random.randint(1, 15)*quantity
    carbohydrate = random.randint(1, 75)*quantity    
    fat = random.randint(1, 30)*quantity
    calories = protein*4 + carbohydrate*4 + fat*9    
    product = ""
    product = product + str(calories) + "," + str(protein) + "," + str(carbohydrate) + "," + str(fat) + "," + str(random.randint(50, 200)) + "," + str(random.randint(800, 4000)) + "|"    
    return product
def createFat():
    quantity = 1*random.randint(5,10)    
    protein = random.randint(1, 15)*quantity
    carbohydrate = random.randint(1, 37)*quantity    
    fat = random.randint(1, 80)*quantity
    calories = protein*4 + carbohydrate*4 +fat*9    
    product = ""
    product = product + str(calories) + "," + str(protein) + "," + str(carbohydrate) + "," + str(fat) + "," + str(random.randint(50, 200)) + "," + str(random.randint(800, 4000)) + "|"    
    return product
def createGroceries(n):
    longitud = 0    
    groceries = "[|"
    for i in range(0,math.floor(n/3)):        
        groceries = groceries + createProtein()
        longitud = longitud + 1    
    for i in range(0,math.floor(n/3)):
        groceries = groceries + createCarbohydrate()        
        longitud = longitud + 1
    for i in range(0,math.floor(n/3)):        
        groceries = groceries + createFat()
        longitud = longitud + 1    
    for i in range(n-longitud):
        groceries = groceries + createCarbohydrate()        
        longitud = longitud + 1
    groceries = groceries + "]"    
    print("Len Groceries:"+ str(longitud))
    return groceries
def printGroceries(n):    
    groceries = "groceries = " + str(createGroceries(n))
    return groceries
def createRequirements(d, p):    #Redondear holgura < 2
    holgura = 1.1    
    minprot = 38*d*p
    maxprot = int(46*d*p*holgura)    
    mincar = 200*d*p
    maxcar = int(200*d*p*holgura)    
    minfat = 57*d*p
    maxfat = int(62*d*p*holgura)    
    mincal = minprot*4 + mincar*4 + minfat*9
    maxcal = maxprot*4 + maxcar*4 + maxfat*9    
    requirements = "[|" + str(mincal) + "," + str(maxcal) + "|" + str(minprot) + "," + str(maxprot) + "|" + str(mincar) + "," + str(maxcar) + "|" + str(minfat) + "," + str(maxfat) + "|]"
    return requirements
def printRequirements(d, p):    
    requirements = "requirements = " + str(createRequirements(d, p)) 
    return requirements
def printBudget(d,p):
    budget = "budget = " + str(int(50000*d*p))
    return budget
def createDZN(n): 
    days = random.randint(1, 4)
    people = random.randint(1, 4)
    dzn = printN(n) + ";\n" + printBudget(days,people) + ";\n" + printGroceries(n) + ";\n" + printRequirements(days, people) + ";"    
    print(dzn)
    return(dzn)
#with open('/Users/juanj/Desktop/data.dzn', 'w') as f:#    f.write(createDZN(100))
# PRUEBAS:
#    days = 7#    people = 1

# %%
def create_IL(n):
    for i in range(n):
        path = '../instances/'+str(i)+'.dzn'
        #print(model)
        with open(path, 'w', encoding='utf8') as file_object:
            file_object.write(createDZN(random.randint(10, 30)))
        print('created: Instance',i)

create_IL(50)
# Out:
# Len Groceries:10
# n = 10;
# budget = 200000;
# groceries = [|2947,84,196,203,186,1900|1413,252,81,9,196,1752|2728,40,120,232,122,3507|2934,126,324,126,114,800|1393,7,231,49,60,2762|1710,75,60,130,89,3185|3008,120,200,192,184,3337|4293,81,324,297,87,3213|2510,50,15,250,160,3172|2328,48,156,168,53,1036|];
# requirements = [|5860,6776|152,202|800,880|228,272|];
# created: Instance 0
# Len Groceries:13
# n = 13;
# budget = 150000;
# groceries = [|3015,153,135,207,52,2976|3030,100,230,190,87,3302|1470,130,35,90,153,3142|2445,150,135,145,154,2829|4923,45,639,243,186,3973|2408,70,91,196,87,1865|2912,14,336,168,75,2880|1820,35,357,28,89,1583|1165,75,25,85,99,1642|2034,24,120,162,93,1449|6390,80,190,590,132,2556|4842,66,186,426,199,2036|1370,75,20,110,156,1799|];
# requirements = [|4395,5080|114,151|600,660|171,204|];
# created: Instance 1
# Len Groceries:11
# n = 11;
# budget = 300000;
# groceries = [|2828,168,224,140,116,1423|2604,14,196,196,179,2398|384,18,24,24,167,3347|3380,90,260,220,53,2242|4360,30,610,200,132,3126|1855,35,260,75,153,3665|3440,65,120,300,58,1868|1744,80,248,48,197,3670|3712,8,272,288,140,2818|1925,75,170,105,94,2658|3184,96,232,208,64,3442|];
# requirements = [|8790,10173|228,303|1200,1320|342,409|];
# created: Instance 2
# Len Groceries:13
# n = 13;
# budget = 150000;
# groceries = [|2640,112,224,144,121,1894|1880,170,30,120,182,937|1212,150,18,60,142,1048|3339,45,243,243,95,2599|2336,56,168,160,188,3725|2250,60,390,50,53,1802|2808,112,536,24,151,2792|2112,96,216,96,126,3243|8440,90,310,760,115,3540|2300,40,175,160,78,2954|2180,50,270,100,174,3190|2979,45,234,207,71,834|2984,120,176,200,111,3972|];
# requirements = [|4395,5080|114,151|600,660|171,204|];
# created: Instance 3
# Len Groceries:10
# n = 10;
# budget = 150000;
# groceries = [|1611,36,144,99,140,3215|2457,203,112,133,92,3963|2800,210,175,140,77,2855|3152,56,192,240,101,844|3880,100,600,120,181,3061|575,50,15,35,140,3681|2395,5,110,215,178,3468|5040,117,171,432,79,1562|5075,84,161,455,132,3143|1855,30,130,135,183,2016|];
# requirements = [|4395,5080|114,151|600,660|171,204|];
# created: Instance 4
# Len Groceries:13
# n = 13;
# budget = 400000;
# groceries = [|2055,85,170,115,71,1577|1360,95,110,60,170,1799|1500,72,114,84,52,3049|1020,60,105,40,91,821|1305,27,117,81,171,3601|468,42,48,12,84,3338|1624,7,84,140,77,1992|2552,32,480,56,102,2787|2990,80,150,230,121,1886|4905,117,36,477,92,3775|6288,72,168,592,123,2558|6660,20,340,580,73,2480|2860,130,180,180,73,2970|];
# requirements = [|11720,13561|304,404|1600,1760|456,545|];
# created: Instance 5
# Len Groceries:12
# n = 12;
# budget = 200000;
# groceries = [|1808,112,232,48,62,1574|1040,24,56,80,120,2320|2259,243,180,63,199,1349|3000,90,210,200,105,2296|1053,54,27,81,74,3125|4179,98,490,203,58,2686|1407,7,77,119,87,2525|1296,24,138,72,115,914|7100,30,80,740,156,3022|7190,60,50,750,162,2089|4968,32,40,520,63,2786|4060,120,130,340,162,3858|];
# requirements = [|5860,6776|152,202|800,880|228,272|];
# created: Instance 6
# Len Groceries:10
# n = 10;
# budget = 800000;
# groceries = [|1816,104,224,56,93,2566|2984,120,104,232,55,3379|2562,28,203,182,191,2492|2296,56,140,168,108,942|2472,48,264,136,93,1654|3528,7,434,196,178,2937|4060,60,10,420,171,1902|2705,65,15,265,165,3577|4208,16,136,400,56,1059|472,16,48,24,179,1914|];
# requirements = [|23440,27135|608,809|3200,3520|912,1091|];
# created: Instance 7
# Len Groceries:10
# n = 10;
# budget = 400000;
# groceries = [|3528,216,216,200,126,3982|3890,200,300,210,133,2174|1110,15,105,70,118,1292|2480,70,325,100,171,2282|4113,108,414,225,194,3478|1812,66,198,84,130,1807|4356,72,126,396,141,1056|3969,105,210,301,73,3758|3760,5,80,380,94,3690|4930,20,740,210,109,2589|];
# requirements = [|11720,13561|304,404|1600,1760|456,545|];
# created: Instance 8
# Len Groceries:12
# n = 12;
# budget = 400000;
# groceries = [|1900,40,210,100,95,1446|1284,96,144,36,130,3777|2611,105,154,175,119,3167|1872,135,90,108,183,869|1115,35,75,75,183,3046|1330,35,95,90,54,2870|1674,66,150,90,195,3197|830,45,50,50,155,954|2760,30,300,160,83,1611|3608,8,48,376,150,3366|1720,60,280,40,126,838|2933,56,252,189,91,2297|];
# requirements = [|11720,13561|304,404|1600,1760|456,545|];
# created: Instance 9
